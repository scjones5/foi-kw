# %%
import requests
response2010 = requests.get("https://opendata.arcgis.com/datasets/a47ef9f046d442808c306dfd59ec2f7c_0/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json")
response1998 = requests.get("https://opendata.arcgis.com/datasets/d056d3e23558481bbd99376e1718d0a3_0/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json")
response1997 = requests.get("https://opendata.arcgis.com/datasets/fcfa7d6ada794969bbed357e4bd85294_0/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json")
response1996 = requests.get("https://opendata.arcgis.com/datasets/76f77c2b2d864689bc0fc9adfbf690f7_0/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json")
response1995 = requests.get("https://opendata.arcgis.com/datasets/f362b8c4652d49d6bbb7a59478132caf_0/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json")
response1992 = requests.get("https://opendata.arcgis.com/datasets/a59f7b37fcc540438a63b36035ca0068_0/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json")
response2003 = requests.get("https://opendata.arcgis.com/datasets/02223f9066294cadb1737234d5ccc5ab_0/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json")
response2004 = requests.get("https://opendata.arcgis.com/datasets/78ab0cb401c349fa95c16b83d7e5d194_0/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json")
response2005 = requests.get("https://opendata.arcgis.com/datasets/bde5696c88654b6d84ae5ad7f6c910b6_0/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json")
response1993 = requests.get("https://opendata.arcgis.com/datasets/5f3c2930f4e4459ea66c6765a1b3bd88_0/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json")
response2000 = requests.get("https://opendata.arcgis.com/datasets/f218c27832da4fa083eb7b7c7dc1afec_0/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json")
response2002 = requests.get("https://opendata.arcgis.com/datasets/39f6b9d302354b2bbe044220c10621fd_0/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json")
response2007 = requests.get("https://opendata.arcgis.com/datasets/ad3e9afade7a4542839c562adfaff15e_0/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json")
response2008 = requests.get("https://opendata.arcgis.com/datasets/ebdd6808d748465689e343427cd8bf2f_0/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json")
response2006 = requests.get("https://opendata.arcgis.com/datasets/6b85448141bd4186850540e49189ce9d_0/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json")
response1994 = requests.get("https://opendata.arcgis.com/datasets/8c7ecc63062f470ab0793159cd7fbd8b_0/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json")
response1999 = requests.get("https://opendata.arcgis.com/datasets/a89b670d719a4d77a9190db4c456be3e_0/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json")
response2001 = requests.get("https://opendata.arcgis.com/datasets/a5f9ee5558e94e8fb6db498c1a318863_0/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json")
response2011 = requests.get("https://opendata.arcgis.com/datasets/d20e0fe797ac49f2b5033f81f754763d_0/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json")
response2012 = requests.get("https://opendata.arcgis.com/datasets/19105a10a66043a0802094650964935d_0/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json")
response2013 = requests.get("https://opendata.arcgis.com/datasets/66e434b25b234814831bd46baf9b7619_0/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json")
response2014 = requests.get("https://opendata.arcgis.com/datasets/dcd52c58025d4e6dbd6c188362f4322d_0/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json")
response2015 = requests.get("https://opendata.arcgis.com/datasets/c4327fc9ba164100a806bc9244b73908_0/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json")
response2016 = requests.get("https://opendata.arcgis.com/datasets/31937f8462c347188bb06796f73442df_0/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json")
response2009 = requests.get("https://opendata.arcgis.com/datasets/f2ab29afe873498f824492d114f80dc7_0/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json")
responses = [response1993, response1994, response1995, response1996, response1997, response1998, response1999, response2000, response2001, response2002, response2003, response2004, response2005, response2006, response2007, 
             response2008, response2009, response2010, response2011, response2012, response2013, response2014, response2015, response2016]

# %%
import json
data2010 = response2010.json()

# %%
for key in data2010.keys():
    print(key)
# Out:
# objectIdFieldName
# globalIdFieldName
# hasZ
# hasM
# spatialReference
# fields
# features
# exceededTransferLimit

# %%
print(data2010["features"][0]['attributes'])
print(data2010["features"][0]['attributes']["Summary_of_Request"])
print(len(data2010["features"]))
# Out:
# {'Request_Number': 2010001, 'Request_Type': 'General Information', 'Source': 'Business', 'Summary_of_Request': 'Phase I environmental site assessment for {address removed}, North Dumfries.', 'Decision': 'No records exist', 'OBJECTID': 0}
# Phase I environmental site assessment for {address removed}, North Dumfries.
# 29

# %%
import pandas as pd
from pandas.io.json import json_normalize
df2010 = json_normalize(data2010["features"])

# %%
df2010.head()
# Out:
#   attributes.Decision  attributes.OBJECTID  attributes.Request_Number  \
# 0    No records exist                    0                    2010001
# 1    No records exist                    1                    2010002
# 2    No records exist                    2                    2010003
# 3       All disclosed                    3                    2010004
# 4       All disclosed                    4                    2010005
#
#   attributes.Request_Type    attributes.Source  \
# 0     General Information             Business
# 1     General Information             Business
# 2     General Information             Business
# 3     General Information               Public
# 4     General Information  Individual by Agent
#
#                        attributes.Summary_of_Request
# 0  Phase I environmental site assessment for {add...
# 1  Phase I environmental site assessment for {add...
# 2  Phase I environmental site assessment for {add...
# 3  Contract issued to {company name removed} rela...
# 4  Food product complaint investigation for pumpk...

# %%
all_df = pd.DataFrame()
# in 2014, some of the columns had an extra ':' afterward, so fix the column headings here
colnames = ['Decision', 'OBJECTID', 'Request_Number', 'Request_Type', 'Source', 'Summary_of_Request']
for response in responses:
    data = response.json()
    df = json_normalize(data["features"])
    df.columns = colnames
    all_df = all_df.append(df)

# %%
print(df2010.columns)
print(all_df.columns)
print(all_df.columns.difference(df.columns))
print(len(df.columns.difference(all_df.columns)))
# Out:
# Index(['attributes.Decision', 'attributes.OBJECTID',
#        'attributes.Request_Number', 'attributes.Request_Type',
#        'attributes.Source', 'attributes.Summary_of_Request'],
#       dtype='object')
# Index(['Decision', 'OBJECTID', 'Request_Number', 'Request_Type', 'Source',
#        'Summary_of_Request'],
#       dtype='object')
# Index([], dtype='object')
# 0

# %%
all_df.head()
# Out:
#               Decision  OBJECTID  Request_Number          Request_Type  \
# 0        All disclosed         0           93001   General Information
# 1  Partly non-existent         1           93002  Personal Information
# 2      Partly exempted         2           93003  Personal Information
# 3        All disclosed         3           93004  Personal Information
# 4        All disclosed         4           93005   General Information
#
#                 Source                                 Summary_of_Request
# 0               Public  Notes written by members of the Maintenance Re...
# 1  Individual by Agent  Director's submission regarding SARB appeal an...
# 2               Public  Performance evaluations, probationary report, ...
# 3  Individual by Agent  Details of support assignment on assistance pa...
# 4               Public  Weigh slips for landfill truck and ticket issu...

# %% [markdown]
# ### For now, let's try to predict from Summary_of_Request only

# %%
features = ['Decision', 'Summary_of_Request']
all_df = all_df[features]
all_df.columns = ['Decision', 'Request_summary']
# Do feature importance with other stuff?

# %%
print(all_df['Decision'].value_counts())
print(len(all_df['Decision'].value_counts()))
# Check out fuzzywuzzy
# Out:
# All disclosed                                      238
# Partly exempted                                    197
# Withdrawn                                          116
# No records exist                                    54
# Information disclosed in part                       50
# Partly non-existent                                 32
# Nothing disclosed                                   28
# No record exists                                    21
# All Information disclosed                           16
# Forwarded out                                       15
# All information disclosed                           13
# Abandoned                                           13
# No responsive records exist                         11
# Non-existent                                         3
# Correction refused                                   3
# Transferred to Region of Waterloo Public Health      2
# Correction made                                      2
# All disclosed                                        2
# No additional records exist                          1
# Transferred                                          1
# Correction granted                                   1
# Request withdrawn                                    1
# No information disclosed                             1
# Statement of disagreement filed                      1
# Name: Decision, dtype: int64
# 24

# %%
all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 822 entries, 0 to 81
# Data columns (total 2 columns):
# Decision           822 non-null object
# Request_summary    822 non-null object
# dtypes: object(2)
# memory usage: 19.3+ KB

# %%
all_df.isnull().sum()
# Out:
# Decision           0
# Request_summary    0
# dtype: int64

# %% [markdown]
# ### Or, we could use fuzzy string matching

# %%
from fuzzywuzzy import fuzz

all_df_clean = all_df.copy()

for row in all_df['Decision'].unique():
    for row2 in all_df['Decision'].unique():
        matching_result = fuzz.ratio(row, row2) # could be ratio, partial_ratio, token_set_ratio, token_sort_ratio 
        if matching_result > 80:
            #print(row, row2)
            #print(matching_results)
            #Combine if match found
            all_df_clean['Decision'][all_df_clean['Decision'] == row2] = row
            
print(all_df_clean['Decision'].value_counts())
print(len(all_df_clean['Decision'].unique()))
# Out:
# All disclosed                                      240
# Partly exempted                                    197
# Withdrawn                                          116
# No records exist                                    75
# Information disclosed in part                       50
# Partly non-existent                                 32
# No information disclosed                            30
# Nothing disclosed                                   28
# Forwarded out                                       15
# Abandoned                                           13
# No responsive records exist                         11
# Non-existent                                         3
# Correction refused                                   3
# Correction made                                      2
# Transferred to Region of Waterloo Public Health      2
# No additional records exist                          1
# Transferred                                          1
# Correction granted                                   1
# Request withdrawn                                    1
# Statement of disagreement filed                      1
# Name: Decision, dtype: int64
# 20

# %%
all_df_pr = all_df.copy()

for row in all_df['Decision'].unique():
    for row2 in all_df['Decision'].unique():
        matching_result = fuzz.partial_ratio(row, row2) # could be ratio, partial_ratio, token_set_ratio, token_sort_ratio 
        if matching_result > 80:
            #print(row, row2)
            #print(matching_results)
            #Combine if match found
            all_df_pr['Decision'][all_df_pr['Decision'] == row2] = row
            
print(all_df_pr['Decision'].value_counts())
print(len(all_df_pr['Decision'].unique()))
# Out:
# All disclosed                      240
# Partly exempted                    197
# Request withdrawn                  117
# No responsive records exist         87
# No information disclosed            80
# Non-existent                        35
# Nothing disclosed                   28
# Forwarded out                       15
# Abandoned                           13
# Transferred                          3
# Correction refused                   3
# Correction made                      2
# Statement of disagreement filed      1
# Correction granted                   1
# Name: Decision, dtype: int64
# 14

# %%
all_df_tsr = all_df.copy()

for row in all_df['Decision'].unique():
    for row2 in all_df['Decision'].unique():
        matching_result = fuzz.token_sort_ratio(row, row2) # could be ratio, partial_ratio, token_set_ratio, token_sort_ratio 
        if matching_result > 80:
            #print(row, row2)
            #print(matching_results)
            #Combine if match found
            all_df_tsr['Decision'][all_df_tsr['Decision'] == row2] = row
            
print(all_df_tsr['Decision'].value_counts())
print(len(all_df_tsr['Decision'].unique()))
# Out:
# All disclosed                                      240
# Partly exempted                                    197
# Withdrawn                                          116
# No information disclosed                            80
# No records exist                                    75
# Partly non-existent                                 32
# Nothing disclosed                                   28
# Forwarded out                                       15
# Abandoned                                           13
# No responsive records exist                         11
# Correction refused                                   3
# Non-existent                                         3
# Transferred to Region of Waterloo Public Health      2
# Correction made                                      2
# Correction granted                                   1
# Transferred                                          1
# No additional records exist                          1
# Request withdrawn                                    1
# Statement of disagreement filed                      1
# Name: Decision, dtype: int64
# 19

# %%
all_df_tokset = all_df.copy()

for row in all_df['Decision'].unique():
    for row2 in all_df['Decision'].unique():
        matching_result = fuzz.token_set_ratio(row, row2) # could be ratio, partial_ratio, token_set_ratio, token_sort_ratio 
        if matching_result > 80:
            #print(row, row2)
            #print(matching_results)
            #Combine if match found
            all_df_tokset['Decision'][all_df_tokset['Decision'] == row2] = row
            
print(all_df_tokset['Decision'].value_counts())
print(len(all_df_tokset['Decision'].unique()))
# Out:
# No information disclosed           348
# Partly exempted                    197
# Request withdrawn                  117
# No responsive records exist         87
# Non-existent                        35
# Forwarded out                       15
# Abandoned                           13
# Transferred                          3
# Correction refused                   3
# Correction made                      2
# Statement of disagreement filed      1
# Correction granted                   1
# Name: Decision, dtype: int64
# 12

# %%
all_df_pr['Decision'].loc[all_df_pr['Decision'] == "Abandoned"] = "Request withdrawn"
all_df_pr['Decision'].loc[all_df_pr['Decision'] == "Non-existent"] = "No responsive records exist"
all_df_pr['Decision'].loc[all_df_pr['Decision'] == "No information disclosed "] = "Nothing disclosed"
all_df_pr['Decision'].loc[all_df_pr['Decision'] == "Transferred"] = "Forwarded out"
all_df_pr['Decision'].loc[all_df_pr['Decision'] == "Correction granted"] = "Correction made"
print(all_df_pr['Decision'].value_counts())
# Out:
# All disclosed                      240
# Partly exempted                    197
# Request withdrawn                  130
# No responsive records exist        122
# Nothing disclosed                  108
# Forwarded out                       18
# Correction made                      3
# Correction refused                   3
# Statement of disagreement filed      1
# Name: Decision, dtype: int64

# %%
all_df_over20 = all_df_pr.groupby('Decision').filter(lambda x: len(x) > 20)
print(all_df_over20['Decision'].value_counts())
# Out:
# All disclosed                  240
# Partly exempted                197
# Request withdrawn              130
# No responsive records exist    122
# Nothing disclosed              108
# Name: Decision, dtype: int64

# %%
# encode the target variable as an integer
all_df_over20['category_id'] = all_df_over20['Decision'].factorize()[0]
# Out:
# /Users/sjones/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
category_id_df = all_df_over20[['Decision', 'category_id']].drop_duplicates().sort_values('category_id')

# %%
category_id_df.head()
# Out:
#                        Decision  category_id
# 0                All disclosed             0
# 1   No responsive records exist            1
# 2               Partly exempted            2
# 26            Request withdrawn            3
# 24            Nothing disclosed            4

# %%
category_to_id = dict(category_id_df.values)
print(category_to_id)
id_to_category = dict(category_id_df[['category_id', 'Decision']].values)
print(id_to_category)
# Out:
# {'All disclosed ': 0, 'No responsive records exist': 1, 'Partly exempted': 2, 'Request withdrawn': 3, 'Nothing disclosed': 4}
# {0: 'All disclosed ', 1: 'No responsive records exist', 2: 'Partly exempted', 3: 'Request withdrawn', 4: 'Nothing disclosed'}

# %%
all_df_over20.head()
# Out:
#                       Decision  \
# 0               All disclosed
# 1  No responsive records exist
# 2              Partly exempted
# 3               All disclosed
# 4               All disclosed
#
#                                      Request_summary  category_id
# 0  Notes written by members of the Maintenance Re...            0
# 1  Director's submission regarding SARB appeal an...            1
# 2  Performance evaluations, probationary report, ...            2
# 3  Details of support assignment on assistance pa...            0
# 4  Weigh slips for landfill truck and ticket issu...            0

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8,6))
all_df_over20.groupby('Decision').Request_summary.count().plot.bar(ylim=0)
plt.show()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', 
                       encoding='latin-1', ngram_range=(1,2), stop_words='english')

features = tfidf.fit_transform(all_df_over20.Request_summary).toarray()
labels = all_df_over20.category_id
features.shape
# Out:
# /Users/sjones/anaconda/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# (797, 374)

# %%
from sklearn.feature_selection import chi2
import numpy as np

N=2
for Decision, category_id in sorted(category_to_id.items()):
    features_chi2 = chi2(features, labels == category_id)
    indices = np.argsort(features_chi2[0])
    feature_names = np.array(tfidf.get_feature_names())[indices]
    unigrams = [v for v in feature_names if len(v.split(' ')) ==1]
    bigrams = [v for v in feature_names if len(v.split(' ')) ==2]
    print("# '{}':".format(Decision))
    print("  . Most correlated unigrams:\n. {}".format('\n.'.join(unigrams[-N:])))
    print("  . Most correlated bigrams:\n. {}".format('\n.'.join(bigrams[-N:])))
# Out:
# # 'All disclosed ':
#   . Most correlated unigrams:
# . assistance
# .personal
#   . Most correlated bigrams:
# . information removed
# .removed competition
# # 'No responsive records exist':
#   . Most correlated unigrams:
# . site
# .phase
#   . Most correlated bigrams:
# . assessment address
# .site assessment
# # 'Nothing disclosed':
#   . Most correlated unigrams:
# . bus
# .2014
#   . Most correlated bigrams:
# . complete ontario
# .works file
# # 'Partly exempted':
#   . Most correlated unigrams:
# . competition
# .94
#   . Most correlated bigrams:
# . information competition
# .rabies control
# # 'Request withdrawn':
#   . Most correlated unigrams:
# . provincial
# .evaluation
#   . Most correlated bigrams:
# . treatment plant
# .provincial offences

# %% [markdown]
# ### Naive Bayes Classifier

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB

X_train, X_test, y_train, y_test = train_test_split(all_df_over20['Request_summary'], all_df_over20['Decision'], random_state=0)
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

clf = MultinomialNB().fit(X_train_tfidf, y_train)
# Out:
# /Users/sjones/anaconda/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):

# %% [markdown]
# ### Try our model out with a prediction

# %%
print(clf.predict(count_vect.transform(["All correspondence related to the traffic accident."])))
# Out:
# ['Nothing disclosed']

# %%
import warnings
warnings.filterwarnings(action='once')
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC

from sklearn.model_selection import cross_val_score

models = [
    RandomForestClassifier(n_estimators=200, max_depth=3,
                          random_state=0), #, class_weight='balanced'),
    LinearSVC(), #class_weight='balanced'),
    MultinomialNB(),
    LogisticRegression(random_state=0)#, class_weight='balanced'),
]
CV=5
cv_df = pd.DataFrame(index=range(CV * len(models)))
entries=[]
for model in models:
    model_name = model.__class__.__name__
    accuracies = cross_val_score(model, features, labels,
                                scoring='accuracy', cv=CV)
    for fold_idx, accuracy in enumerate(accuracies):
        entries.append((model_name, fold_idx, accuracy))
cv_df = pd.DataFrame(entries, columns=['model_name', 'fold_idx', 'accuracy'])

import seaborn as sns

sns.boxplot(x='model_name', y='accuracy', data=cv_df)
sns.stripplot(x='model_name', y='accuracy', data=cv_df,
             size=8, jitter=True, edgecolor="gray", linewidth=2)
plt.show()
# Out:
# /Users/sjones/anaconda/lib/python3.6/importlib/_bootstrap.py:205: ImportWarning: can't resolve package from __spec__ or __package__, falling back on __name__ and __path__
#   return f(*args, **kwds)
# /Users/sjones/anaconda/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# /Users/sjones/anaconda/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/sjones/anaconda/lib/python3.6/importlib/_bootstrap.py:205: ImportWarning: can't resolve package from __spec__ or __package__, falling back on __name__ and __path__
#   return f(*args, **kwds)
# /Users/sjones/anaconda/lib/python3.6/site-packages/seaborn/categorical.py:454: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)

# %%
cv_df.groupby('model_name').accuracy.mean()
# Bagging (other than rf)
# boosting (adaboost, xgboost)
# shallow NN (one layer only)
# CNN model
# RNN (LSTM/ bi-directional LSTM)
# Hierarchical Attention Network (HAN)
# GIU?
# kNN (with Bag of Words/ compare against tfidf) / clustering on classes 
# Flair library (ensemble text classifier)
# AutoML
# Out:
# model_name
# LinearSVC                 0.362882
# LogisticRegression        0.398066
# MultinomialNB             0.398152
# RandomForestClassifier    0.349038
# Name: accuracy, dtype: float64

# %%
model = MultinomialNB()

X_train, X_test, y_train, y_test, indices_train, indices_test = train_test_split(features, 
                                                        labels, all_df_over20.index, test_size=0.33, random_state=0)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

from sklearn.metrics import confusion_matrix 
conf_mat = confusion_matrix(y_test, y_pred)
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(conf_mat, annot=True, fmt='d',
           xticklabels=category_id_df.Decision.values,
           yticklabels=category_id_df.Decision.values)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

from sklearn import metrics
print(metrics.classification_report(y_test, y_pred,
                                   target_names=all_df_over20['Decision'].unique()))
# Out:
# /Users/sjones/anaconda/lib/python3.6/site-packages/seaborn/matrix.py:143: DeprecationWarning: elementwise == comparison failed; this will raise an error in the future.
#   if xticklabels == []:
#                              precision    recall  f1-score   support
#
#              All disclosed        0.36      0.69      0.47        67
# No responsive records exist       0.50      0.49      0.49        41
#             Partly exempted       0.58      0.48      0.53        73
#           Request withdrawn       0.38      0.11      0.17        47
#           Nothing disclosed       0.58      0.39      0.47        36
#
#                 avg / total       0.48      0.45      0.44       264

# %%
model = RandomForestClassifier(random_state=0, max_depth=3, n_estimators=200)#, class_weight='balanced')

X_train, X_test, y_train, y_test, indices_train, indices_test = train_test_split(features, 
                                                        labels, all_df_over20.index, test_size=0.33, random_state=0)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

from sklearn.metrics import confusion_matrix 

conf_mat = confusion_matrix(y_test, y_pred)
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(conf_mat, annot=True, fmt='d',
           xticklabels=category_id_df.Decision.values,
           yticklabels=category_id_df.Decision.values)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

from sklearn import metrics
print(metrics.classification_report(y_test, y_pred,
                                   target_names=all_df_over20['Decision'].unique()))
# Out:
# /Users/sjones/anaconda/lib/python3.6/site-packages/seaborn/matrix.py:143: DeprecationWarning: elementwise == comparison failed; this will raise an error in the future.
#   if xticklabels == []:
#                              precision    recall  f1-score   support
#
#              All disclosed        0.29      0.91      0.43        67
# No responsive records exist       0.65      0.41      0.51        41
#             Partly exempted       0.69      0.15      0.25        73
#           Request withdrawn       0.00      0.00      0.00        47
#           Nothing disclosed       0.50      0.11      0.18        36
#
#                 avg / total       0.43      0.35      0.28       264
# /Users/sjones/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
model = LogisticRegression(random_state=0)#, class_weight='balanced')

X_train, X_test, y_train, y_test, indices_train, indices_test = train_test_split(features, 
                                                        labels, all_df_over20.index, test_size=0.33, random_state=0)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

from sklearn.metrics import confusion_matrix 

conf_mat = confusion_matrix(y_test, y_pred)
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(conf_mat, annot=True, fmt='d',
           xticklabels=category_id_df.Decision.values,
           yticklabels=category_id_df.Decision.values)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

from sklearn import metrics
print(metrics.classification_report(y_test, y_pred,
                                   target_names=all_df_over20['Decision'].unique()))
# Out:
# /Users/sjones/anaconda/lib/python3.6/site-packages/seaborn/matrix.py:143: DeprecationWarning: elementwise == comparison failed; this will raise an error in the future.
#   if xticklabels == []:
#                              precision    recall  f1-score   support
#
#              All disclosed        0.35      0.73      0.47        67
# No responsive records exist       0.62      0.49      0.55        41
#             Partly exempted       0.49      0.42      0.46        73
#           Request withdrawn       0.42      0.11      0.17        47
#           Nothing disclosed       0.53      0.25      0.34        36
#
#                 avg / total       0.47      0.43      0.41       264

# %%
model = LinearSVC()#class_weight='balanced')

X_train, X_test, y_train, y_test, indices_train, indices_test = train_test_split(features, 
                                                        labels, all_df_over20.index, test_size=0.33, random_state=0)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

from sklearn.metrics import confusion_matrix 

conf_mat = confusion_matrix(y_test, y_pred)
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(conf_mat, annot=True, fmt='d',
           xticklabels=category_id_df.Decision.values,
           yticklabels=category_id_df.Decision.values)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

from sklearn import metrics
print(metrics.classification_report(y_test, y_pred,
                                   target_names=all_df_over20['Decision'].unique()))
# Out:
# /Users/sjones/anaconda/lib/python3.6/site-packages/seaborn/matrix.py:143: DeprecationWarning: elementwise == comparison failed; this will raise an error in the future.
#   if xticklabels == []:
#                              precision    recall  f1-score   support
#
#              All disclosed        0.35      0.48      0.41        67
# No responsive records exist       0.50      0.49      0.49        41
#             Partly exempted       0.44      0.45      0.45        73
#           Request withdrawn       0.39      0.26      0.31        47
#           Nothing disclosed       0.59      0.44      0.51        36
#
#                 avg / total       0.44      0.43      0.43       264

# %% [markdown]
# ### Let's look at where the errors are occurring

# %%
from IPython.display import display

for predicted in category_id_df.category_id:
    for actual in category_id_df.category_id:
        if predicted != actual and conf_mat[actual, predicted] >=5:
            print("'{}' predicted as '{}' : {} examples.".format(id_to_category[actual], id_to_category[predicted],
                                                                conf_mat[actual, predicted]))
            display(all_df_over20.loc[indices_test[(y_test == actual) & (y_pred == predicted)]][['Decision',
                                                                                         'Request_summary']])
            print('')
# Out:
# 'No responsive records exist' predicted as 'All disclosed ' : 10 examples.
#                        Decision  \
# 15              Partly exempted
# 15              Partly exempted
# 15               All disclosed
# 15            Request withdrawn
# 15            Request withdrawn
# 15  No responsive records exist
# 15               All disclosed
# 15               All disclosed
# 15              Partly exempted
# 15               All disclosed
# 15               All disclosed
# 15            Request withdrawn
# 15  No responsive records exist
# 15  No responsive records exist
# 15              Partly exempted
# 15              Partly exempted
# 15  No responsive records exist
# 15               All disclosed
# 15               All disclosed
# 15            Nothing disclosed
# 15            Nothing disclosed
# 15            Request withdrawn
# 24               All disclosed
# 24               All disclosed
# 24            Nothing disclosed
# 24               All disclosed
# 24  No responsive records exist
# 24              Partly exempted
# 24               All disclosed
# 24               All disclosed
# ..                          ...
# 21               All disclosed
# 21  No responsive records exist
# 21               All disclosed
# 21              Partly exempted
# 21            Nothing disclosed
# 21            Nothing disclosed
# 7                All disclosed
# 7                All disclosed
# 7                All disclosed
# 7                All disclosed
# 7                All disclosed
# 7   No responsive records exist
# 7             Request withdrawn
# 7               Partly exempted
# 7                All disclosed
# 7                All disclosed
# 7                All disclosed
# 7   No responsive records exist
# 7                All disclosed
# 7                All disclosed
# 7               Partly exempted
# 7                All disclosed
# 7   No responsive records exist
# 7                All disclosed
# 7                All disclosed
# 7                All disclosed
# 7               Partly exempted
# 7             Request withdrawn
# 7             Nothing disclosed
# 7             Nothing disclosed
#
#                                       Request_summary
# 15  Human Resources Personal File for {name removed}.
# 15  Food Poisoning Records regarding {location rem...
# 15  Screening records for {name removed} in Compet...
# 15  Report by Senior Staff to Councillors/Review C...
# 15  Ten schedules from service agreement for opera...
# 15  Records regarding filter materials supplied by...
# 15  Financial records documenting {name removed} e...
# 15  Grand River Transit contract for outdoor bench...
# 15  All records related to Environmentally Sensiti...
# 15  Social Worker client file pertaining to {name ...
# 15  Food premise inspections of {location removed}...
# 15  Childcare providers and agencies receiving fun...
# 15  File 6 (supervisor's file) of Human Resources ...
# 15  Number and type of section 22 orders issued un...
# 15  Environmental Enforcement Services investigati...
# 15  Phase I environmental site assessment for {add...
# 15  Phase I environmental site assessment for {add...
# 15  Phase I environmental site assessment for {add...
# 15  Multiple transportation operations and enginee...
# 15  Any and all records related to {organization n...
# 15  Copy of {name removed} complete Ontario Works ...
# 15  Phase One Environmental Site Assessment for 20...
# 24  Interview notes and other records related to s...
# 24  A complete copy of Income Maintenance client f...
# 24  Letter about {name removed} sent by {name remo...
# 24  All records regarding the Family Awareness Cen...
# 24  By-Law officer's notes regarding charges again...
# 24  Home Child Care Provider file for {name removed}.
# 24  Emergency Medical Services and Waterloo Region...
# 24  Phase I environmental site assessment for {add...
# ..                                                ...
# 21  Three environmental reports submitted with a s...
# 21  A complete copy of Ontario Works client file f...
# 21  A complete copy of Ontario Works client file f...
# 21  Any and all correspondence between the Regiona...
# 21  Video footage taken on the number 8 bus to Fai...
# 21  1) What was the scheduled shift for Paramedics...
# 7   Pricing for supplies and rentals regarding the...
# 7   A complete copy of Income Maintenance client f...
# 7   All personal file records for {name removed} p...
# 7   Information concerning decision to deny vocati...
# 7   7 information items regarding construction con...
# 7   GWA for {name removed} records from January 1,...
# 7   Number of contracts and dollar amount of contr...
# 7   Public Health Inspection reports and laborator...
# 7   Names of contractors and quotes for Request fo...
# 7   Rabies incident report records regarding May 2...
# 7   Information about {name removed} and children ...
# 7   A complete copy of Ontario Works client file f...
# 7   Phase I environmental site assessment {address...
# 7   Rights and responsibilities form dated March 2...
# 7   Rabies control investigation records affecting...
# 7   Transportation Operations records for all road...
# 7   Phase I environmental site assessment for {add...
# 7   A complete copy of Ontario Works client file f...
# 7   Phase I environmental site assessment for {add...
# 7     Winning bid for blueprinting services for 2012.
# 7   Proposal PQ2012-03 - Preston WWTP; notes, eval...
# 7   Phase I environemntal site assesment for {addr...
# 7   Complete file regarding {name removed} dog att...
# 7   Any environmental records that the Region of W...
#
# [219 rows x 2 columns]
# 'Partly exempted' predicted as 'All disclosed ' : 28 examples.
#                        Decision  \
# 7                All disclosed
# 7                All disclosed
# 7                All disclosed
# 7                All disclosed
# 7                All disclosed
# 7   No responsive records exist
# 7             Request withdrawn
# 7               Partly exempted
# 7                All disclosed
# 7                All disclosed
# 7                All disclosed
# 7   No responsive records exist
# 7                All disclosed
# 7                All disclosed
# 7               Partly exempted
# 7                All disclosed
# 7   No responsive records exist
# 7                All disclosed
# 7                All disclosed
# 7                All disclosed
# 7               Partly exempted
# 7             Request withdrawn
# 7             Nothing disclosed
# 7             Nothing disclosed
# 55              Partly exempted
# 55              Partly exempted
# 55            Nothing disclosed
# 2               Partly exempted
# 2               Partly exempted
# 2             Request withdrawn
# ..                          ...
# 17  No responsive records exist
# 17            Request withdrawn
# 17               All disclosed
# 17              Partly exempted
# 17              Partly exempted
# 17              Partly exempted
# 17            Nothing disclosed
# 17            Nothing disclosed
# 10              Partly exempted
# 10              Partly exempted
# 10              Partly exempted
# 10            Request withdrawn
# 10  No responsive records exist
# 10               All disclosed
# 10  No responsive records exist
# 10               All disclosed
# 10              Partly exempted
# 10  No responsive records exist
# 10            Request withdrawn
# 10            Request withdrawn
# 10              Partly exempted
# 10              Partly exempted
# 10  No responsive records exist
# 10  No responsive records exist
# 10  No responsive records exist
# 10               All disclosed
# 10            Request withdrawn
# 10  No responsive records exist
# 10            Nothing disclosed
# 10            Request withdrawn
#
#                                       Request_summary
# 7   Pricing for supplies and rentals regarding the...
# 7   A complete copy of Income Maintenance client f...
# 7   All personal file records for {name removed} p...
# 7   Information concerning decision to deny vocati...
# 7   7 information items regarding construction con...
# 7   GWA for {name removed} records from January 1,...
# 7   Number of contracts and dollar amount of contr...
# 7   Public Health Inspection reports and laborator...
# 7   Names of contractors and quotes for Request fo...
# 7   Rabies incident report records regarding May 2...
# 7   Information about {name removed} and children ...
# 7   A complete copy of Ontario Works client file f...
# 7   Phase I environmental site assessment {address...
# 7   Rights and responsibilities form dated March 2...
# 7   Rabies control investigation records affecting...
# 7   Transportation Operations records for all road...
# 7   Phase I environmental site assessment for {add...
# 7   A complete copy of Ontario Works client file f...
# 7   Phase I environmental site assessment for {add...
# 7     Winning bid for blueprinting services for 2012.
# 7   Proposal PQ2012-03 - Preston WWTP; notes, eval...
# 7   Phase I environemntal site assesment for {addr...
# 7   Complete file regarding {name removed} dog att...
# 7   Any environmental records that the Region of W...
# 55  Restaurant inspection reports for {location re...
# 55  Information regarding {name removed} applicati...
# 55  Complete copy of Ontario Works file for {name ...
# 2   Performance evaluations, probationary report, ...
# 2         Competition Files 93-390,93-391,and 93-392.
# 2   Records of calls to 976 and 1-900 numbers made...
# ..                                                ...
# 17  Phase I environmental site assessment for {loc...
# 17  A complete copy of Ontario Works client file f...
# 17  Phase I environmental site assessments for {ad...
# 17  Request for Proposal P2012-11 pricing of winni...
# 17  A complete copy of Ontario Works client file f...
# 17  A complete copy of Ontario Works client file f...
# 17  Site Conditions on Property surrounding 420 Pi...
# 17  1) Records for the past two years up to most c...
# 10  Contents of GWA client file for {name removed}...
# 10  Pay equity information: 1) Job descriptions, 4...
# 10  Scores, notes and information regarding {name ...
# 10  Amounts paid for severances, retirements and v...
# 10  Complete fiscal year end vendor report for yea...
# 10  Copy of {company name removed} tender bid for ...
# 10  Receipts or other records regarding sale of tr...
# 10  A copy of Ontario Works client file for {name ...
# 10  Rabies control records from an incident occurr...
# 10  Four records of correspondence from Ontario Wo...
# 10  Successful bid and contract for cleaning servi...
# 10  Ambulance Call Report for Emergency Medical Se...
# 10             Collision database in electronic form.
# 10  Work orders and invoices for two companies: {c...
# 10  Phase I environmental site assessment for {add...
# 10  Phase I environmental site assessment for {add...
# 10  Receipt provided to Ontario Works client {name...
# 10  A complete copy of Ontario Works client file f...
# 10  Phase I environmental site assessment for {add...
# 10  A complete copy of Ontario Works client file f...
# 10  A list of company names and addresses that wer...
# 10  All prequalification proposals, scores, debrie...
#
# [512 rows x 2 columns]
# 'Request withdrawn' predicted as 'All disclosed ' : 16 examples.
#                        Decision  \
# 26            Request withdrawn
# 26              Partly exempted
# 26               All disclosed
# 26            Request withdrawn
# 26               All disclosed
# 26               All disclosed
# 26               All disclosed
# 26  No responsive records exist
# 26              Partly exempted
# 26              Partly exempted
# 26            Nothing disclosed
# 26  No responsive records exist
# 2               Partly exempted
# 2               Partly exempted
# 2             Request withdrawn
# 2             Nothing disclosed
# 2             Nothing disclosed
# 2   No responsive records exist
# 2               Partly exempted
# 2               Partly exempted
# 2               Partly exempted
# 2               Partly exempted
# 2   No responsive records exist
# 2               Partly exempted
# 2               Partly exempted
# 2   No responsive records exist
# 2                All disclosed
# 2             Request withdrawn
# 2             Nothing disclosed
# 2   No responsive records exist
# ..                          ...
# 14            Request withdrawn
# 14              Partly exempted
# 14              Partly exempted
# 14               All disclosed
# 14            Nothing disclosed
# 14            Request withdrawn
# 5                All disclosed
# 5             Request withdrawn
# 5               Partly exempted
# 5               Partly exempted
# 5                All disclosed
# 5               Partly exempted
# 5                All disclosed
# 5                All disclosed
# 5   No responsive records exist
# 5                All disclosed
# 5   No responsive records exist
# 5               Partly exempted
# 5                All disclosed
# 5             Request withdrawn
# 5               Partly exempted
# 5                All disclosed
# 5   No responsive records exist
# 5   No responsive records exist
# 5   No responsive records exist
# 5             Request withdrawn
# 5                All disclosed
# 5             Request withdrawn
# 5             Nothing disclosed
# 5             Request withdrawn
#
#                                       Request_summary
# 26  A complete copy of Income Maintenance client f...
# 26  A complete copy of Income Maintenance client f...
# 26  Personal information for {name removed} in Com...
# 26  Complaint regarding alleged fraud accusation m...
# 26  Ambulance Call Reports related to {address rem...
# 26  A complete copy of Ontario Works client file f...
# 26  Food premise inspection records for {restauran...
# 26  A complete copy of Ontario Works client file f...
# 26  Taxi owner, driver, broker identity and relate...
# 26  A complete copy of Ontario Works client file f...
# 26      Complete Ontario Works file of {name removed}
# 26  Follow up to request 2016018  for 1) Traffic S...
# 2   Performance evaluations, probationary report, ...
# 2         Competition Files 93-390,93-391,and 93-392.
# 2   Records of calls to 976 and 1-900 numbers made...
# 2   Identity of complainant regarding Public Healt...
# 2   Records regarding workplace harassment investi...
# 2   Information regarding damage to Regional facil...
# 2   Public Health inspection records for {location...
# 2   Public Health Inspection reports and records r...
# 2   All records regarding St. Clements Pumping Sta...
# 2       Identity of owner of closed restaurant {name
# 2   Cost of surveillance by Waterloo Regional Poli...
# 2   Technical specifications and maintenance recor...
# 2   Phase I environmental site assessment for {add...
# 2   Pages 1 and 2 of fax sent April 30, 2003 conta...
# 2   Traffic signal sequence and timing at {interse...
# 2   A complete copy of Ontario Works client file f...
# 2   Ambulance Call Report for {address removed}, W...
# 2   Phase I environmental site assessment for {add...
# ..                                                ...
# 14  Phase I environmental site assessment for{addr...
# 14  Specifications and price sheets for tanker tru...
# 14  Arborist inspection, complaints, tree maintena...
# 14  A complete copy of Ontario Works client file f...
# 14  Complete copy of {name removed} Ontario Works ...
# 14  Phase One Environmental Site Assessment for 65...
# 5   Complaint sent to Income Maintenance by Police...
# 5   Food and beverage receipts for Waterloo Region...
# 5   Other applicants' information in Competition F...
# 5   Information regarding benzene contamination in...
# 5   Records in Human Resources regarding date of s...
# 5   Tender and contract for wastewater treatment o...
# 5   Public Health inspection file for {name remove...
# 5   Public Health Inspection report dated March 20...
# 5   Location of contaminated sites near {address r...
# 5   Planning records related to Paradise Lake Sett...
# 5   Number of promoted employees/new hires aged 55...
# 5   Rabies control investigation from April 2003 r...
# 5                  Employee file and attendance data.
# 5   Radio logs; Operations Centre log; and Patrol ...
# 5   Health Protection and Promotion Act Orders iss...
# 5   Septic system permit records for {addresses re...
# 5   Phase I environmental site assessment for {add...
# 5   A complete copy of Ontario Works client file f...
# 5   Phase I environmental site assessment for {add...
# 5   Information about land holdings related to ben...
# 5   Multiple transportation operations and enginee...
# 5   A complete copy of Ontario Works client file f...
# 5   Copy of {name removed} complete Ontario Works ...
# 5   All records concerning {name removed} in the p...
#
# [335 rows x 2 columns]
# 'Nothing disclosed' predicted as 'All disclosed ' : 5 examples.
#                        Decision  \
# 12              Partly exempted
# 12            Request withdrawn
# 12  No responsive records exist
# 12            Request withdrawn
# 12              Partly exempted
# 12              Partly exempted
# 12               All disclosed
# 12            Request withdrawn
# 12  No responsive records exist
# 12              Partly exempted
# 12              Partly exempted
# 12            Nothing disclosed
# 12              Partly exempted
# 12              Partly exempted
# 12  No responsive records exist
# 12  No responsive records exist
# 12               All disclosed
# 12              Partly exempted
# 12  No responsive records exist
# 12              Partly exempted
# 12               All disclosed
# 12            Nothing disclosed
# 12            Nothing disclosed
# 9               Partly exempted
# 9                All disclosed
# 9   No responsive records exist
# 9                All disclosed
# 9             Request withdrawn
# 9                All disclosed
# 9             Request withdrawn
# ..                          ...
# 9   No responsive records exist
# 9             Nothing disclosed
# 9             Request withdrawn
# 66               All disclosed
# 66            Nothing disclosed
# 14              Partly exempted
# 14              Partly exempted
# 14              Partly exempted
# 14               All disclosed
# 14            Request withdrawn
# 14               All disclosed
# 14               All disclosed
# 14              Partly exempted
# 14               All disclosed
# 14              Partly exempted
# 14            Request withdrawn
# 14               All disclosed
# 14               All disclosed
# 14               All disclosed
# 14  No responsive records exist
# 14               All disclosed
# 14  No responsive records exist
# 14            Request withdrawn
# 14            Request withdrawn
# 14              Partly exempted
# 14              Partly exempted
# 14               All disclosed
# 14            Nothing disclosed
# 14            Request withdrawn
# 75            Nothing disclosed
#
#                                       Request_summary
# 12  Information pertaining to FBA overpayment for ...
# 12  Investigation records regarding salmonella ber...
# 12  Notes regarding contact between Ministry of So...
# 12  Various Personal Information Banks held by the...
# 12  Income Maintenance file for {name removed} nar...
# 12  Rabies control records related to dog bite aff...
# 12  Access to client/family data in Healthy Babies...
# 12  Technical and operating manuals for laser spee...
# 12  Contract or leases for garbage disposal from 1...
# 12  Public Health Inspection records regarding {lo...
# 12                 Rabies control investigation file.
# 12  Employment information regarding deceased comm...
# 12  A complete copy of Ontario Works client file {...
# 12  Submissions provided for Request for Proposal ...
# 12  Authority to fluoridate water outside of Water...
# 12  Phase I environmental site assessment for {add...
# 12  A complete copy of Ontario Works client file f...
# 12  Records related to sidewalk repairs, inspectio...
# 12  Phase I environmental site assessment for {add...
# 12  Lease, negotiations and breakdown of costs for...
# 12  A complete copy of Ontario Works client file f...
# 12  Any environmental concerns files regarding pre...
# 12  Any and all records, emails and correspondence...
# 9   General information on job competitions (5) So...
# 9   Health Inspection reports for {location remove...
# 9   Complaints/violations regarding {location remo...
# 9   All information about {name removed} held by S...
# 9   Details of payouts to {name removed} on retire...
# 9   Income Maintenance file for {name removed} nar...
# 9   Phase I environmental site assessment regardin...
# ..                                                ...
# 9   A complete copy of Ontario Works client file f...
# 9   Copy of the video from the Grand River Transit...
# 9   Complete copy of the Ontario Works file for {n...
# 66  Correspondence to Income Maintenance caseworke...
# 66  Names of security guards working at the Ainsli...
# 14    General Information in Competition File 93-070.
# 14  A complete copy of Income Maintenance client f...
# 14    Screening records for Competition File 94-450.
# 14  Records indicating {name removed} residence fr...
# 14  Form 4 medical assessment and last 6 months of...
# 14  Narrative notes in Income Maintenance file for...
# 14  Records relating to complaint about {location ...
# 14  A complete copy of Ontario Works client file f...
# 14  Contract between Grand River Transit and {comp...
# 14  All records related to Environmentally Sensiti...
# 14  Records regarding reconstruction of Weber Stre...
# 14  Food-borne illness incident records from {loca...
# 14  1) sign out sheets for buses based at 250 Stra...
# 14  Contract between Region of Waterloo and {compa...
# 14  Complaint related to food premise inspection r...
# 14          Subdivision file RP1694, Wilmot Township.
# 14  Phase I environmental site assessment for {add...
# 14  Records relating to overpayment in Ontario Wor...
# 14  Phase I environmental site assessment for{addr...
# 14  Specifications and price sheets for tanker tru...
# 14  Arborist inspection, complaints, tree maintena...
# 14  A complete copy of Ontario Works client file f...
# 14  Complete copy of {name removed} Ontario Works ...
# 14  Phase One Environmental Site Assessment for 65...
# 75  Copy of the statements obtained from anyone di...
#
# [73 rows x 2 columns]
# 'All disclosed ' predicted as 'No responsive records exist' : 7 examples.
#                        Decision  \
# 29              Partly exempted
# 29               All disclosed
# 29               All disclosed
# 29               All disclosed
# 29               All disclosed
# 29            Request withdrawn
# 29               All disclosed
# 29               All disclosed
# 29               All disclosed
# 29  No responsive records exist
# 29            Nothing disclosed
# 33               All disclosed
# 33              Partly exempted
# 33              Partly exempted
# 33            Request withdrawn
# 33               All disclosed
# 33            Request withdrawn
# 33            Nothing disclosed
# 33            Nothing disclosed
# 2               Partly exempted
# 2               Partly exempted
# 2             Request withdrawn
# 2             Nothing disclosed
# 2             Nothing disclosed
# 2   No responsive records exist
# 2               Partly exempted
# 2               Partly exempted
# 2               Partly exempted
# 2               Partly exempted
# 2   No responsive records exist
# ..                          ...
# 22  No responsive records exist
# 22               All disclosed
# 22              Partly exempted
# 22              Partly exempted
# 22            Nothing disclosed
# 22  No responsive records exist
# 2               Partly exempted
# 2               Partly exempted
# 2             Request withdrawn
# 2             Nothing disclosed
# 2             Nothing disclosed
# 2   No responsive records exist
# 2               Partly exempted
# 2               Partly exempted
# 2               Partly exempted
# 2               Partly exempted
# 2   No responsive records exist
# 2               Partly exempted
# 2               Partly exempted
# 2   No responsive records exist
# 2                All disclosed
# 2             Request withdrawn
# 2             Nothing disclosed
# 2   No responsive records exist
# 2                All disclosed
# 2                All disclosed
# 2                All disclosed
# 2             Nothing disclosed
# 2             Nothing disclosed
# 2             Nothing disclosed
#
#                                       Request_summary
# 29    General Information in Competition File 93-221.
# 29  Personal Information for {name removed} in two...
# 29  Home Care client chart for {name removed} from...
# 29  Phase I environmental site assessment for {add...
# 29  Two spill investigation reports prepared by En...
# 29  Phase I environmental site assessment for{addr...
# 29  All records related to the Comprehensive Revie...
# 29  Video recording from Grand River Transit bus r...
# 29  A file search for tobacco on {company name and...
# 29  Report of any outstanding work orders or defic...
# 29  Records with respect to any incidents that occ...
# 33  Letter from Victoria Park Community Homes Mana...
# 33  Personal information held by supervisors in En...
# 33  A complete copy of Income Maintenance client f...
# 33      Records related to the draft backflow by-law.
# 33  Phase I environmental site assessment for {add...
# 33  Phase I environmental site assessment for {add...
# 33      Complete Ontario Works file of {name removed}
# 33  Any Correspondence between the City of Cambrid...
# 2   Performance evaluations, probationary report, ...
# 2         Competition Files 93-390,93-391,and 93-392.
# 2   Records of calls to 976 and 1-900 numbers made...
# 2   Identity of complainant regarding Public Healt...
# 2   Records regarding workplace harassment investi...
# 2   Information regarding damage to Regional facil...
# 2   Public Health inspection records for {location...
# 2   Public Health Inspection reports and records r...
# 2   All records regarding St. Clements Pumping Sta...
# 2       Identity of owner of closed restaurant {name
# 2   Cost of surveillance by Waterloo Regional Poli...
# ..                                                ...
# 22  Phase I environmental site assessment for {add...
# 22  Phase I Environmental site assessment for {add...
# 22  Contract with City of Guelph for organics proc...
# 22  Project agreement between Region of Waterloo a...
# 22  1.�Doon Valley Manor Supportive Housing assess...
# 22  Health Department records, for the property lo...
# 2   Performance evaluations, probationary report, ...
# 2         Competition Files 93-390,93-391,and 93-392.
# 2   Records of calls to 976 and 1-900 numbers made...
# 2   Identity of complainant regarding Public Healt...
# 2   Records regarding workplace harassment investi...
# 2   Information regarding damage to Regional facil...
# 2   Public Health inspection records for {location...
# 2   Public Health Inspection reports and records r...
# 2   All records regarding St. Clements Pumping Sta...
# 2       Identity of owner of closed restaurant {name
# 2   Cost of surveillance by Waterloo Regional Poli...
# 2   Technical specifications and maintenance recor...
# 2   Phase I environmental site assessment for {add...
# 2   Pages 1 and 2 of fax sent April 30, 2003 conta...
# 2   Traffic signal sequence and timing at {interse...
# 2   A complete copy of Ontario Works client file f...
# 2   Ambulance Call Report for {address removed}, W...
# 2   Phase I environmental site assessment for {add...
# 2   Phase 1 Environmental site assessment for {add...
# 2   Signage placement and changes to signage at Ho...
# 2   A list of expenses related to a presentation b...
# 2   Records related to the dismissal of {name and ...
# 2   A file search for tobacco on Big Bear Food Mar...
# 2   Copies of public health inspection reports for...
#
# [130 rows x 2 columns]
# 'Request withdrawn' predicted as 'No responsive records exist' : 5 examples.
#                        Decision  \
# 46              Partly exempted
# 46            Request withdrawn
# 46               All disclosed
# 46            Nothing disclosed
# 39               All disclosed
# 39              Partly exempted
# 39            Request withdrawn
# 39            Nothing disclosed
# 39            Nothing disclosed
# 28               All disclosed
# 28               All disclosed
# 28               All disclosed
# 28              Partly exempted
# 28  No responsive records exist
# 28               All disclosed
# 28            Request withdrawn
# 28            Request withdrawn
# 28              Partly exempted
# 28  No responsive records exist
# 28            Nothing disclosed
# 28  No responsive records exist
# 27               All disclosed
# 27            Request withdrawn
# 27              Partly exempted
# 27               All disclosed
# 27            Request withdrawn
# 27               All disclosed
# 27               All disclosed
# 27            Request withdrawn
# 27               All disclosed
# 27               All disclosed
# 27            Nothing disclosed
# 27            Nothing disclosed
# 10              Partly exempted
# 10              Partly exempted
# 10              Partly exempted
# 10            Request withdrawn
# 10  No responsive records exist
# 10               All disclosed
# 10  No responsive records exist
# 10               All disclosed
# 10              Partly exempted
# 10  No responsive records exist
# 10            Request withdrawn
# 10            Request withdrawn
# 10              Partly exempted
# 10              Partly exempted
# 10  No responsive records exist
# 10  No responsive records exist
# 10  No responsive records exist
# 10               All disclosed
# 10            Request withdrawn
# 10  No responsive records exist
# 10            Nothing disclosed
# 10            Request withdrawn
#
#                                       Request_summary
# 46  General Information in Competition Files 93-29...
# 46      Road conditions and snow clearing operations.
# 46  List of companies paying a sewer surcharge inc...
# 46  Complete copy of Ontario Works file for {name ...
# 39  GWA client file for {name removed} benefits te...
# 39  Human Resources Personal File for {name removed}.
# 39  Phase I environmental site assessment for {add...
# 39  Report compiled by Public Health Inspector, Ca...
# 39  Complete copy of Ontario Works file for {name ...
# 28  Personal Information for {name removed} in Com...
# 28  Various records regarding intersection {inters...
# 28  Personal information for {name removed} in Com...
# 28  Environmental Enforcement Services incident re...
# 28  Phase I environmental site assessments for {lo...
# 28  Phase I environmental site assessment for {add...
# 28  Phase I environmental site assessment for {add...
# 28  Phase I environmental site assessment for parc...
# 28  Records related to Official Plan Amendment 25 ...
# 28  Notes of the nurse/employee who visited {name ...
# 28      Complete Ontario Works file of {name removed}
# 28  Advise if your records indicate whether 1250 W...
# 27    General Information in Competition File 93-228.
# 27  A complete copy of Income Maintenance client f...
# 27  Interview scores and results regarding intervi...
# 27  Grand River Transit agreement with {company re...
# 27  Phase I environmental site assessment for {add...
# 27  Class environmental assessment for {address re...
# 27  Phase I environmental site assessment for {add...
# 27  Phase I Environmental site assessment for parc...
# 27  Grand River Transit bus video of requester suf...
# 27  GRT Bus 2416 outside video footage from {date ...
# 27      Complete Ontario Works file of {name removed}
# 27  A complete copy of all records, documents, and...
# 10  Contents of GWA client file for {name removed}...
# 10  Pay equity information: 1) Job descriptions, 4...
# 10  Scores, notes and information regarding {name ...
# 10  Amounts paid for severances, retirements and v...
# 10  Complete fiscal year end vendor report for yea...
# 10  Copy of {company name removed} tender bid for ...
# 10  Receipts or other records regarding sale of tr...
# 10  A copy of Ontario Works client file for {name ...
# 10  Rabies control records from an incident occurr...
# 10  Four records of correspondence from Ontario Wo...
# 10  Successful bid and contract for cleaning servi...
# 10  Ambulance Call Report for Emergency Medical Se...
# 10             Collision database in electronic form.
# 10  Work orders and invoices for two companies: {c...
# 10  Phase I environmental site assessment for {add...
# 10  Phase I environmental site assessment for {add...
# 10  Receipt provided to Ontario Works client {name...
# 10  A complete copy of Ontario Works client file f...
# 10  Phase I environmental site assessment for {add...
# 10  A complete copy of Ontario Works client file f...
# 10  A list of company names and addresses that wer...
# 10  All prequalification proposals, scores, debrie...
# 'Nothing disclosed' predicted as 'No responsive records exist' : 5 examples.
#                        Decision  \
# 21              Partly exempted
# 21               All disclosed
# 21              Partly exempted
# 21              Partly exempted
# 21  No responsive records exist
# 21              Partly exempted
# 21  No responsive records exist
# 21              Partly exempted
# 21            Nothing disclosed
# 21              Partly exempted
# 21            Request withdrawn
# 21            Request withdrawn
# 21            Nothing disclosed
# 21               All disclosed
# 21               All disclosed
# 21               All disclosed
# 21  No responsive records exist
# 21               All disclosed
# 21              Partly exempted
# 21            Nothing disclosed
# 21            Nothing disclosed
# 37              Partly exempted
# 37              Partly exempted
# 37  No responsive records exist
# 37            Request withdrawn
# 37              Partly exempted
# 37              Partly exempted
# 37            Nothing disclosed
# 37            Nothing disclosed
# 17  No responsive records exist
# ..                          ...
# 2             Nothing disclosed
# 2   No responsive records exist
# 2                All disclosed
# 2                All disclosed
# 2                All disclosed
# 2             Nothing disclosed
# 2             Nothing disclosed
# 2             Nothing disclosed
# 19              Partly exempted
# 19              Partly exempted
# 19              Partly exempted
# 19            Request withdrawn
# 19              Partly exempted
# 19            Request withdrawn
# 19            Request withdrawn
# 19            Request withdrawn
# 19               All disclosed
# 19               All disclosed
# 19  No responsive records exist
# 19               All disclosed
# 19              Partly exempted
# 19               All disclosed
# 19  No responsive records exist
# 19               All disclosed
# 19              Partly exempted
# 19              Partly exempted
# 19            Nothing disclosed
# 19              Partly exempted
# 19            Nothing disclosed
# 19            Nothing disclosed
#
#                                       Request_summary
# 21  Sewer surcharge information for companies payi...
# 21  Personal Information for {name removed} in Com...
# 21  Quotation file Q95-1129 including bidders and ...
# 21  Reference and Personal Information for {name r...
# 21  Investigative report on plumbing in {name remo...
# 21  Complaint dated November 1, 1999 in {name remo...
# 21  Rent receipts from 1997 to present in Ontario ...
# 21  Rabies control investigation records regarding...
# 21  Information about requester supplied by {name ...
# 21  Rabies control investigation file regarding do...
# 21  A complete copy of Ontario Works client file {...
# 21  Road closure information from Regional Road 86...
# 21  Allegations and statements about requester sup...
# 21  Request for Proposal P2008-07; cost per unit (...
# 21  A complete copy of Ontario Works client file f...
# 21  Three environmental reports submitted with a s...
# 21  A complete copy of Ontario Works client file f...
# 21  A complete copy of Ontario Works client file f...
# 21  Any and all correspondence between the Regiona...
# 21  Video footage taken on the number 8 bus to Fai...
# 21  1) What was the scheduled shift for Paramedics...
# 37    General Information in Competition File 93-200.
# 37   Interview questions for Competition File 94-225.
# 37  Information regarding the Region's position th...
# 37  All bid prices for bidders regarding Request f...
# 37  A complete copy of Ontario Works client file f...
# 37  Public Health inspection records related to th...
# 37  A full complete accounting of the total cost o...
# 37  6 Environment reports: 1. 2011 Groundwater Mon...
# 17  General Information in Caseworker I, Income Ma...
# ..                                                ...
# 2   Ambulance Call Report for {address removed}, W...
# 2   Phase I environmental site assessment for {add...
# 2   Phase 1 Environmental site assessment for {add...
# 2   Signage placement and changes to signage at Ho...
# 2   A list of expenses related to a presentation b...
# 2   Records related to the dismissal of {name and ...
# 2   A file search for tobacco on Big Bear Food Mar...
# 2   Copies of public health inspection reports for...
# 19  General Information in Competition Files 93-16...
# 19  Home Child Care Provider File for {name removed}.
# 19  Competition file for Senior Clerk Joblink Posi...
# 19  All personal information held by Income Mainte...
# 19  Any correspondence prepared by the Region of W...
# 19  Copies of purchase orders for last 12 months i...
# 19  All records regarding Environmentally Sensitiv...
# 19  Records sent by Sunnyside Home to St. Mary's G...
# 19  A complete copy of Ontario Works client file f...
# 19  Requester's own personal information regarding...
# 19  List of all chlorinated solvent sites in the R...
# 19  Phase I environmental site assessments for {ad...
# 19  Food-borne illness complaint investigation reg...
# 19  Details about Region of Waterloo monitoring we...
# 19  Phase I environmental site assessment for (loc...
# 19  Phase I environmental site assessment for {add...
# 19  Sewer Surcharge Agreement Companies that have ...
# 19              Rabies control investigation records.
# 19  Requester's personal information provided to {...
# 19  All correspondence between the Region of Water...
# 19  Copy of {name removed} complete Ontario Works ...
# 19  Complete copy of the Ontario Works file for {n...
#
# [98 rows x 2 columns]
# 'All disclosed ' predicted as 'Partly exempted' : 21 examples.
#                        Decision  \
# 13               All disclosed
# 13               All disclosed
# 13            Request withdrawn
# 13              Partly exempted
# 13              Partly exempted
# 13              Partly exempted
# 13               All disclosed
# 13              Partly exempted
# 13               All disclosed
# 13  No responsive records exist
# 13               All disclosed
# 13               All disclosed
# 13               All disclosed
# 13  No responsive records exist
# 13  No responsive records exist
# 13              Partly exempted
# 13  No responsive records exist
# 13            Request withdrawn
# 13               All disclosed
# 13  No responsive records exist
# 13            Nothing disclosed
# 13            Request withdrawn
# 27               All disclosed
# 27            Request withdrawn
# 27              Partly exempted
# 27               All disclosed
# 27            Request withdrawn
# 27               All disclosed
# 27               All disclosed
# 27            Request withdrawn
# ..                          ...
# 14            Request withdrawn
# 14               All disclosed
# 14               All disclosed
# 14               All disclosed
# 14  No responsive records exist
# 14               All disclosed
# 14  No responsive records exist
# 14            Request withdrawn
# 14            Request withdrawn
# 14              Partly exempted
# 14              Partly exempted
# 14               All disclosed
# 14            Nothing disclosed
# 14            Request withdrawn
# 23               All disclosed
# 23              Partly exempted
# 23            Request withdrawn
# 23              Partly exempted
# 23              Partly exempted
# 23               All disclosed
# 23  No responsive records exist
# 23               All disclosed
# 23               All disclosed
# 23              Partly exempted
# 23            Request withdrawn
# 23  No responsive records exist
# 23              Partly exempted
# 23               All disclosed
# 23            Request withdrawn
# 23  No responsive records exist
#
#                                       Request_summary
# 13  Personal Information for {name removed} in Com...
# 13  {Name removed} personal information in salmone...
# 13  Home Child Care Provider file for {name removed}.
# 13  All records related to {company name removed} ...
# 13  Home Child Care Provider file for {name removed}.
# 13  Home Child Care Provider file for {name remove...
# 13  Water quality test results of {location remove...
# 13  All files related to {name removed} held by Wa...
# 13  Analysis of sewage composition on {street name...
# 13  Policies, procedures and by-laws regarding the...
# 13  A copy of Ontario Works client file from {name...
# 13  Signal timing and work orders for traffic ligh...
# 13  Correspondence between Region of Waterloo and ...
# 13  Phase I environmental site assessment for {add...
# 13                   Records supporting fluoridation.
# 13  Food-borne Illness investigation regarding e. ...
# 13  Phase I environmental site assessment for {add...
# 13  Phase I environmental site assessment for {add...
# 13  Pool and spa inspection records for {address r...
# 13  Financial reporting, statements and audits for...
# 13  Video footage from a MobilityPLUS vehicle on O...
# 13            Grand River Transit video surveillance.
# 27    General Information in Competition File 93-228.
# 27  A complete copy of Income Maintenance client f...
# 27  Interview scores and results regarding intervi...
# 27  Grand River Transit agreement with {company re...
# 27  Phase I environmental site assessment for {add...
# 27  Class environmental assessment for {address re...
# 27  Phase I environmental site assessment for {add...
# 27  Phase I Environmental site assessment for parc...
# ..                                                ...
# 14  Records regarding reconstruction of Weber Stre...
# 14  Food-borne illness incident records from {loca...
# 14  1) sign out sheets for buses based at 250 Stra...
# 14  Contract between Region of Waterloo and {compa...
# 14  Complaint related to food premise inspection r...
# 14          Subdivision file RP1694, Wilmot Township.
# 14  Phase I environmental site assessment for {add...
# 14  Records relating to overpayment in Ontario Wor...
# 14  Phase I environmental site assessment for{addr...
# 14  Specifications and price sheets for tanker tru...
# 14  Arborist inspection, complaints, tree maintena...
# 14  A complete copy of Ontario Works client file f...
# 14  Complete copy of {name removed} Ontario Works ...
# 14  Phase One Environmental Site Assessment for 65...
# 23  Personal Information for {name removed} in Com...
# 23  Prices for quotation Q94-1149 regarding heavy ...
# 23  Screening criteria and marks for 55 job compet...
# 23  Scores and comments for {name removed} regardi...
# 23  Home Child Care Provider file for {name remove...
# 23  Various records regarding the installation of ...
# 23  Phase I environmental site assessment for {add...
# 23  Work orders and timing for traffic signals at ...
# 23  Phase I environmental site assessment for {add...
# 23  Snow clearing records for Regional Roads that ...
# 23  Phase I environmental site assessment for {add...
# 23  Phase I Environmental site assessment for {add...
# 23  Records pertaining to requester and {company n...
# 23  A complete copy of Ontario Works client file f...
# 23  Any records regarding the RMOW's special counc...
# 23  Complete copy of the Ontario Works file for {n...
#
# [412 rows x 2 columns]
# 'No responsive records exist' predicted as 'Partly exempted' : 6 examples.
#                        Decision  \
# 1   No responsive records exist
# 1             Request withdrawn
# 1             Request withdrawn
# 1                All disclosed
# 1   No responsive records exist
# 1   No responsive records exist
# 1                All disclosed
# 1             Request withdrawn
# 1             Request withdrawn
# 1                All disclosed
# 1                All disclosed
# 1                All disclosed
# 1             Request withdrawn
# 1             Request withdrawn
# 1               Partly exempted
# 1               Partly exempted
# 1   No responsive records exist
# 1             Request withdrawn
# 1             Nothing disclosed
# 1               Partly exempted
# 1   No responsive records exist
# 1   No responsive records exist
# 1             Request withdrawn
# 35              Partly exempted
# 35              Partly exempted
# 35               All disclosed
# 35            Request withdrawn
# 35  No responsive records exist
# 35  No responsive records exist
# 35            Nothing disclosed
# ..                          ...
# 17              Partly exempted
# 17            Request withdrawn
# 17              Partly exempted
# 17              Partly exempted
# 17            Request withdrawn
# 17              Partly exempted
# 17              Partly exempted
# 17               All disclosed
# 17            Request withdrawn
# 17               All disclosed
# 17            Request withdrawn
# 17  No responsive records exist
# 17               All disclosed
# 17  No responsive records exist
# 17  No responsive records exist
# 17            Request withdrawn
# 17               All disclosed
# 17              Partly exempted
# 17              Partly exempted
# 17              Partly exempted
# 17            Nothing disclosed
# 17            Nothing disclosed
# 37              Partly exempted
# 37              Partly exempted
# 37  No responsive records exist
# 37            Request withdrawn
# 37              Partly exempted
# 37              Partly exempted
# 37            Nothing disclosed
# 37            Nothing disclosed
#
#                                       Request_summary
# 1   Director's submission regarding SARB appeal an...
# 1   Groundwater chemistry data supplied by {compan...
# 1   Receipts for food and beverages submitted by W...
# 1     Score for {name removed} in Competition 95-446.
# 1   Copies of food-borne illness complaint reports...
# 1   Records related to construction on {company na...
# ...
# 11  No responsive records exist
# 11              Partly exempted
# 11               All disclosed
# 11            Request withdrawn
# 11  No responsive records exist
# 11            Request withdrawn
# 17  No responsive records exist
# 17              Partly exempted
# 17            Request withdrawn
# 17              Partly exempted
# 17              Partly exempted
# 17            Request withdrawn
# 17              Partly exempted
# 17              Partly exempted
# 17               All disclosed
# 17            Request withdrawn
# 17               All disclosed
# 17            Request withdrawn
# 17  No responsive records exist
# 17               All disclosed
# 17  No responsive records exist
# 17  No responsive records exist
# 17            Request withdrawn
# 17               All disclosed
# 17              Partly exempted
# 17              Partly exempted
# 17              Partly exempted
# 17            Nothing disclosed
# 17            Nothing disclosed
#
#                                       Request_summary
# 14    General Information in Competition File 93-070.
# 14  A complete copy of Income Maintenance client f...
# 14    Screening records for Competition File 94-450.
# 14  Records indicating {name removed} residence fr...
# 14  Form 4 medical assessment and last 6 months of...
# 14  Narrative notes in Income Maintenance file for...
# 14  Records relating to complaint about {location ...
# 14  A complete copy of Ontario Works client file f...
# 14  Contract between Grand River Transit and {comp...
# 14  All records related to Environmentally Sensiti...
# 14  Records regarding reconstruction of Weber Stre...
# 14  Food-borne illness incident records from {loca...
# 14  1) sign out sheets for buses based at 250 Stra...
# 14  Contract between Region of Waterloo and {compa...
# 14  Complaint related to food premise inspection r...
# 14          Subdivision file RP1694, Wilmot Township.
# 14  Phase I environmental site assessment for {add...
# 14  Records relating to overpayment in Ontario Wor...
# 14  Phase I environmental site assessment for{addr...
# 14  Specifications and price sheets for tanker tru...
# 14  Arborist inspection, complaints, tree maintena...
# 14  A complete copy of Ontario Works client file f...
# 14  Complete copy of {name removed} Ontario Works ...
# 14  Phase One Environmental Site Assessment for 65...
# 31                GWA client file for {name removed}.
# 31  Statements and submissions related to harassme...
# 31  Investigation report for glass contaminated pi...
# 31  Phase I environmental site assessment for {add...
# 31  Phase I environmental site assessment for {add...
# 31  18 items relating to Housing Services Division...
# ..                                                ...
# 11  Request for Proposal bid of HSI; correspondenc...
# 11  Phase I environmental site assessment for {add...
# 11  Assessments and related records concerning sol...
# 11  Food-borne illness complaint records for {comp...
# 11  A complete copy of Ontario Works client file f...
# 11  Copy of {name removed} Ontario Works File from...
# 11  All request for proposals, scores, debriefs, p...
# 17  General Information in Caseworker I, Income Ma...
# 17  Geotechnical report for septic system at {addr...
# 17  Competition File for Senior Clerk Joblink Posi...
# 17  Declaration sworn by {name removed} and allega...
# 17  Home Child Care Provider file for {name remove...
# 17  All files relating to tendering, construction,...
# 17  Any and all records regarding a multi vehicle ...
# 17  Certificates of Approval regarding sewage slud...
# 17  Roads needs studies from 1990 to 1994 in relat...
# 17  Records regarding the disposal of sewage sludg...
# 17  Phase I environmental site assessment for {add...
# 17  Request for Proposal 2005-24 including technic...
# 17  Records related to construction at {intersecti...
# 17  A complete copy of Ontario Works client file f...
# 17  Phase I environmental site assessment for {add...
# 17  Phase I environmental site assessment for {loc...
# 17  A complete copy of Ontario Works client file f...
# 17  Phase I environmental site assessments for {ad...
# 17  Request for Proposal P2012-11 pricing of winni...
# 17  A complete copy of Ontario Works client file f...
# 17  A complete copy of Ontario Works client file f...
# 17  Site Conditions on Property surrounding 420 Pi...
# 17  1) Records for the past two years up to most c...
#
# [85 rows x 2 columns]
# 'Partly exempted' predicted as 'Request withdrawn' : 7 examples.
#                        Decision  \
# 13               All disclosed
# 13               All disclosed
# 13            Request withdrawn
# 13              Partly exempted
# 13              Partly exempted
# 13              Partly exempted
# 13               All disclosed
# 13              Partly exempted
# 13               All disclosed
# 13  No responsive records exist
# 13               All disclosed
# 13               All disclosed
# 13               All disclosed
# 13  No responsive records exist
# 13  No responsive records exist
# 13              Partly exempted
# 13  No responsive records exist
# 13            Request withdrawn
# 13               All disclosed
# 13  No responsive records exist
# 13            Nothing disclosed
# 13            Request withdrawn
# 50              Partly exempted
# 50               All disclosed
# 50              Partly exempted
# 50            Request withdrawn
# 10              Partly exempted
# 10              Partly exempted
# 10              Partly exempted
# 10            Request withdrawn
# ..                          ...
# 6             Nothing disclosed
# 21              Partly exempted
# 21               All disclosed
# 21              Partly exempted
# 21              Partly exempted
# 21  No responsive records exist
# 21              Partly exempted
# 21  No responsive records exist
# 21              Partly exempted
# 21            Nothing disclosed
# 21              Partly exempted
# 21            Request withdrawn
# 21            Request withdrawn
# 21            Nothing disclosed
# 21               All disclosed
# 21               All disclosed
# 21               All disclosed
# 21  No responsive records exist
# 21               All disclosed
# 21              Partly exempted
# 21            Nothing disclosed
# 21            Nothing disclosed
# 33               All disclosed
# 33              Partly exempted
# 33              Partly exempted
# 33            Request withdrawn
# 33               All disclosed
# 33            Request withdrawn
# 33            Nothing disclosed
# 33            Nothing disclosed
#
#                                       Request_summary
# 13  Personal Information for {name removed} in Com...
# 13  {Name removed} personal information in salmone...
# 13  Home Child Care Provider file for {name removed}.
# 13  All records related to {company name removed} ...
# 13  Home Child Care Provider file for {name removed}.
# 13  Home Child Care Provider file for {name remove...
# 13  Water quality test results of {location remove...
# 13  All files related to {name removed} held by Wa...
# 13  Analysis of sewage composition on {street name...
# 13  Policies, procedures and by-laws regarding the...
# 13  A copy of Ontario Works client file from {name...
# 13  Signal timing and work orders for traffic ligh...
# 13  Correspondence between Region of Waterloo and ...
# 13  Phase I environmental site assessment for {add...
# 13                   Records supporting fluoridation.
# 13  Food-borne Illness investigation regarding e. ...
# 13  Phase I environmental site assessment for {add...
# 13  Phase I environmental site assessment for {add...
# 13  Pool and spa inspection records for {address r...
# 13  Financial reporting, statements and audits for...
# 13  Video footage from a MobilityPLUS vehicle on O...
# 13            Grand River Transit video surveillance.
# 50  Human Resources File Personal File for {name r...
# 50  Confirmation of ownership status of {name remo...
# 50  Criteria for assessing interpersonal skills an...
# 50  Records involving any environmental contaminat...
# 10  Contents of GWA client file for {name removed}...
# 10  Pay equity information: 1) Job descriptions, 4...
# 10  Scores, notes and information regarding {name ...
# 10  Amounts paid for severances, retirements and v...
# ..                                                ...
# 6   Complete copy of the Ontario Works file for {n...
# 21  Sewer surcharge information for companies payi...
# 21  Personal Information for {name removed} in Com...
# 21  Quotation file Q95-1129 including bidders and ...
# 21  Reference and Personal Information for {name r...
# 21  Investigative report on plumbing in {name remo...
# 21  Complaint dated November 1, 1999 in {name remo...
# 21  Rent receipts from 1997 to present in Ontario ...
# 21  Rabies control investigation records regarding...
# 21  Information about requester supplied by {name ...
# 21  Rabies control investigation file regarding do...
# 21  A complete copy of Ontario Works client file {...
# 21  Road closure information from Regional Road 86...
# 21  Allegations and statements about requester sup...
# 21  Request for Proposal P2008-07; cost per unit (...
# 21  A complete copy of Ontario Works client file f...
# 21  Three environmental reports submitted with a s...
# 21  A complete copy of Ontario Works client file f...
# 21  A complete copy of Ontario Works client file f...
# 21  Any and all correspondence between the Regiona...
# 21  Video footage taken on the number 8 bus to Fai...
# 21  1) What was the scheduled shift for Paramedics...
# 33  Letter from Victoria Park Community Homes Mana...
# 33  Personal information held by supervisors in En...
# 33  A complete copy of Income Maintenance client f...
# 33      Records related to the draft backflow by-law.
# 33  Phase I environmental site assessment for {add...
# 33  Phase I environmental site assessment for {add...
# 33      Complete Ontario Works file of {name removed}
# 33  Any Correspondence between the City of Cambrid...
#
# [123 rows x 2 columns]
# 'Request withdrawn' predicted as 'Nothing disclosed' : 5 examples.
#                        Decision  \
# 36              Partly exempted
# 36              Partly exempted
# 36  No responsive records exist
# 36              Partly exempted
# 36  No responsive records exist
# 36              Partly exempted
# 36            Request withdrawn
# 18               All disclosed
# 18            Request withdrawn
# 18            Request withdrawn
# 18            Request withdrawn
# 18              Partly exempted
# 18               All disclosed
# 18               All disclosed
# 18               All disclosed
# 18               All disclosed
# 18               All disclosed
# 18               All disclosed
# 18               All disclosed
# 18               All disclosed
# 18  No responsive records exist
# 18  No responsive records exist
# 18               All disclosed
# 18               All disclosed
# 18  No responsive records exist
# 18            Request withdrawn
# 18              Partly exempted
# 18  No responsive records exist
# 18            Nothing disclosed
# 20               All disclosed
# ..                          ...
# 20            Nothing disclosed
# 20            Request withdrawn
# 5                All disclosed
# 5             Request withdrawn
# 5               Partly exempted
# 5               Partly exempted
# 5                All disclosed
# 5               Partly exempted
# 5                All disclosed
# 5                All disclosed
# 5   No responsive records exist
# 5                All disclosed
# 5   No responsive records exist
# 5               Partly exempted
# 5                All disclosed
# 5             Request withdrawn
# 5               Partly exempted
# 5                All disclosed
# 5   No responsive records exist
# 5   No responsive records exist
# 5   No responsive records exist
# 5             Request withdrawn
# 5                All disclosed
# 5             Request withdrawn
# 5             Nothing disclosed
# 5             Request withdrawn
# 51              Partly exempted
# 51              Partly exempted
# 51               All disclosed
# 51            Request withdrawn
#
#                                       Request_summary
# 36  Supervisor's notes held by {name removed} in W...
# 36  Personal Information for {name removed} in Com...
# 36  Phase I environmental site assessment on three...
# 36  Records regarding allegations made to Licensin...
# 36  Phase I environmental site assessment for {add...
# 36  Rabies control inspection records for incident...
# 36  Complete copy of the Ontario Works file for {n...
# 18  Personal Information for {name removed} in Cas...
# 18  Inspection records for {location removed} for ...
# 18  {Name removed} personal information from Compe...
# 18  All personal information held by Income Mainte...
# 18  Salary, hiring and job competition records rel...
# 18  Contract between {company name removed} and th...
# 18  Notes from Provincial Offences Court Prosecuto...
# 18  Food-borne illness incident records for {locat...
# 18  Health records of deceased Sunnyside Home resi...
# 18  Phase I environmental site assessment for {loc...
# 18  Technical studies of the Environmental Assessm...
# 18                 Rabies control investigation file.
# 18  A complete copy of Ontario Works client file f...
# 18  Public Health inspection records regarding {ad...
# 18  Phase I environmental site assessment for {add...
# 18  Records related to overpayment in Ontario Work...
# 18    Winning bid for blueprinting services for 2011.
# 18  Phase I environmental site assessment for {add...
# 18  Information relating to the planning and costs...
# 18  A complete copy of Ontario Works client file f...
# 18  Development agreement, all maps as well as com...
# 18  Complete copy of the Ontario Works file for {n...
# 20  Personal Information for {name removed} in Com...
# ..                                                ...
# 20  Complete file regarding {name removed} dog att...
# 20  Complete copy of the Ontario Works file for {i...
# 5   Complaint sent to Income Maintenance by Police...
# 5   Food and beverage receipts for Waterloo Region...
# 5   Other applicants' information in Competition F...
# 5   Information regarding benzene contamination in...
# 5   Records in Human Resources regarding date of s...
# 5   Tender and contract for wastewater treatment o...
# 5   Public Health inspection file for {name remove...
# 5   Public Health Inspection report dated March 20...
# 5   Location of contaminated sites near {address r...
# 5   Planning records related to Paradise Lake Sett...
# 5   Number of promoted employees/new hires aged 55...
# 5   Rabies control investigation from April 2003 r...
# 5                  Employee file and attendance data.
# 5   Radio logs; Operations Centre log; and Patrol ...
# 5   Health Protection and Promotion Act Orders iss...
# 5   Septic system permit records for {addresses re...
# 5   Phase I environmental site assessment for {add...
# 5   A complete copy of Ontario Works client file f...
# 5   Phase I environmental site assessment for {add...
# 5   Information about land holdings related to ben...
# 5   Multiple transportation operations and enginee...
# 5   A complete copy of Ontario Works client file f...
# 5   Copy of {name removed} complete Ontario Works ...
# 5   All records concerning {name removed} in the p...
# 51  Notes held by Manager and Director for {name r...
# 51  Screening and interview notes/results in Compe...
# 51  Income Maintenance client file for {name remov...
# 51  Complete copy of Ontario Works file for {name ...
#
# [78 rows x 2 columns]

# %% [markdown]
# ### Find the terms most correlated with each category

# %%
model.fit(features, labels)
N = 2
for Decision, category_id in sorted(category_to_id.items()):
  #turn the below line on if more than two categories
  #indices = np.argsort(model.coef_[category_id])
  feature_names = np.array(tfidf.get_feature_names()) #[indices]
  unigrams = [v for v in reversed(feature_names) if len(v.split(' ')) == 1][:N]
  bigrams = [v for v in reversed(feature_names) if len(v.split(' ')) == 2][:N]
  print("# '{}':".format(Decision))
  print("  . Top unigrams:\n       . {}".format('\n       . '.join(unigrams)))
  print("  . Top bigrams:\n       . {}".format('\n       . '.join(bigrams)))
# Out:
# # 'All disclosed':
#   . Top unigrams:
#        . years
#        . year
#   . Top bigrams:
#        . works file
#        . works client
# # 'Nothing disclosed':
#   . Top unigrams:
#        . years
#        . year
#   . Top bigrams:
#        . works file
#        . works client

# %% [markdown]
# ### The fact that the above cell returns the same unigrams and bigrams for both 'all disclosed' and 'nothing disclosed' tells us that we probably don't have enough information to be able to separate these cases.

# %% [markdown]
# ### Took a look at adding Toronto data, but would only lead to further class imbalance
